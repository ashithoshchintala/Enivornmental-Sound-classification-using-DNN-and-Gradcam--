# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
pip install numpy pandas matplotlib opencv-python seaborn scikit-learn tensorflow keras pillow tqdm
# Out:
# Collecting numpy
#   Downloading numpy-2.1.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      -------------------------- ----------- 41.0/59.7 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 59.7/59.7 kB 526.6 kB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Collecting keras
#   Downloading keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting pillow
#   Downloading pillow-11.0.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting tqdm
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ashit\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.54.1-cp312-cp312-win_amd64.whl.metadata (167 kB)
#      ---------------------------------------- 0.0/167.0 kB ? eta -:--:--
#      --------------------------- ---------- 122.9/167.0 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 167.0/167.0 kB 3.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\ashit\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting tensorflow-intel==2.17.0 (from tensorflow)
#   Downloading tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading h5py-3.12.1-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading protobuf-4.25.5-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting setuptools (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading setuptools-75.2.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\ashit\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading grpcio-1.67.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting numpy
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# Collecting rich (from keras)
#   Downloading rich-13.9.3-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras)
#   Downloading optree-0.13.0-cp312-cp312-win_amd64.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 48.7/48.7 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\ashit\appdata\roaming\python\python312\site-packages (from tqdm) (0.4.6)
# Collecting markdown-it-py>=2.2.0 (from rich->keras)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ashit\appdata\roaming\python\python312\site-packages (from rich->keras) (2.18.0)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading wheel-0.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Downloading werkzeug-3.0.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.5 MB 2.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/11.5 MB 2.7 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/11.5 MB 2.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.6/11.5 MB 2.7 MB/s eta 0:00:05
#    - -------------------------------------- 0.6/11.5 MB 2.7 MB/s eta 0:00:05
#    - -------------------------------------- 0.6/11.5 MB 2.7 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/11.5 MB 1.6 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/11.5 MB 1.8 MB/s eta 0:00:07
#    --- ------------------------------------ 0.9/11.5 MB 2.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.2/11.5 MB 2.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.4/11.5 MB 2.5 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.5 MB 2.6 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.5 MB 2.7 MB/s eta 0:00:04
#    ------ --------------------------------- 2.0/11.5 MB 2.8 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.5 MB 2.9 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.5 MB 3.0 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/11.5 MB 3.1 MB/s eta 0:00:03
#    --------- ------------------------------ 2.8/11.5 MB 3.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.1/11.5 MB 3.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.3/11.5 MB 3.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.5/11.5 MB 3.4 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.5 MB 3.4 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.5 MB 3.5 MB/s eta 0:00:03
#    -------------- ------------------------- 4.1/11.5 MB 3.5 MB/s eta 0:00:03
#    -------------- ------------------------- 4.1/11.5 MB 3.4 MB/s eta 0:00:03
#    -------------- ------------------------- 4.3/11.5 MB 3.5 MB/s eta 0:00:03
#    --------------- ------------------------ 4.4/11.5 MB 3.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.8/11.5 MB 3.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.9/11.5 MB 3.5 MB/s eta 0:00:02
#    ------------------ --------------------- 5.3/11.5 MB 3.7 MB/s eta 0:00:02
#    ------------------- -------------------- 5.6/11.5 MB 3.8 MB/s eta 0:00:02
#    -------------------- ------------------- 5.9/11.5 MB 3.9 MB/s eta 0:00:02
#    -------------------- ------------------- 5.9/11.5 MB 3.9 MB/s eta 0:00:02
#    --------------------- ------------------ 6.1/11.5 MB 3.8 MB/s eta 0:00:02
#    --------------------- ------------------ 6.2/11.5 MB 3.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.4/11.5 MB 3.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.8/11.5 MB 3.8 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.5 MB 3.8 MB/s eta 0:00:02
#    ------------------------- -------------- 7.4/11.5 MB 3.9 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.5 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 7.7/11.5 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.5 MB 3.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.5 MB 3.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.5/11.5 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.5 MB 4.1 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.5 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.5/11.5 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.5/11.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.9/11.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.1/11.5 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.1/11.5 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.3/11.5 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.5 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.5 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.5 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 4.6 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.2/7.8 MB 6.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/7.8 MB 6.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/7.8 MB 2.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/7.8 MB 4.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/7.8 MB 5.2 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/7.8 MB 4.9 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/7.8 MB 4.6 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/7.8 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/7.8 MB 4.7 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/7.8 MB 4.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/7.8 MB 4.3 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/7.8 MB 4.6 MB/s eta 0:00:02
#    -------------- ------------------------- 2.8/7.8 MB 4.7 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/7.8 MB 4.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.4/7.8 MB 5.1 MB/s eta 0:00:01
#    ------------------ --------------------- 3.6/7.8 MB 5.1 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/7.8 MB 5.4 MB/s eta 0:00:01
#    --------------------- ------------------ 4.3/7.8 MB 5.3 MB/s eta 0:00:01
#    ------------------------ --------------- 4.8/7.8 MB 5.6 MB/s eta 0:00:01
#    ------------------------- -------------- 4.9/7.8 MB 5.4 MB/s eta 0:00:01
#    -------------------------- ------------- 5.1/7.8 MB 5.4 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/7.8 MB 5.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/7.8 MB 5.1 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/7.8 MB 5.1 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/7.8 MB 5.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.5/7.8 MB 4.6 MB/s eta 0:00:01
#    ------------------------------ --------- 5.9/7.8 MB 4.8 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/7.8 MB 4.8 MB/s eta 0:00:01
#    ------------------------------- -------- 6.2/7.8 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 6.4/7.8 MB 4.8 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/7.8 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.7/7.8 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.7/7.8 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/7.8 MB 4.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.9/7.8 MB 4.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.0/7.8 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.8 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/7.8 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  7.8/7.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 4.5 MB/s eta 0:00:00
# Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.4/38.8 MB 13.9 MB/s eta 0:00:03
#     --------------------------------------- 0.6/38.8 MB 10.2 MB/s eta 0:00:04
#     --------------------------------------- 0.7/38.8 MB 6.8 MB/s eta 0:00:06
#    - -------------------------------------- 1.2/38.8 MB 7.9 MB/s eta 0:00:05
#    - -------------------------------------- 1.4/38.8 MB 7.2 MB/s eta 0:00:06
#    - -------------------------------------- 1.4/38.8 MB 5.5 MB/s eta 0:00:07
#    -- ------------------------------------- 2.0/38.8 MB 7.2 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/38.8 MB 7.9 MB/s eta 0:00:05
#    --- ------------------------------------ 2.9/38.8 MB 8.1 MB/s eta 0:00:05
#    --- ------------------------------------ 3.0/38.8 MB 7.4 MB/s eta 0:00:05
#    --- ------------------------------------ 3.1/38.8 MB 7.0 MB/s eta 0:00:06
#    --- ------------------------------------ 3.1/38.8 MB 6.4 MB/s eta 0:00:06
#    --- ------------------------------------ 3.2/38.8 MB 6.1 MB/s eta 0:00:06
#    --- ------------------------------------ 3.2/38.8 MB 5.9 MB/s eta 0:00:07
#    --- ------------------------------------ 3.5/38.8 MB 5.6 MB/s eta 0:00:07
#    --- ------------------------------------ 3.6/38.8 MB 5.8 MB/s eta 0:00:07
#    --- ------------------------------------ 3.7/38.8 MB 5.4 MB/s eta 0:00:07
#    --- ------------------------------------ 3.8/38.8 MB 5.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 3.9/38.8 MB 5.1 MB/s eta 0:00:07
#    ---- ----------------------------------- 4.0/38.8 MB 5.0 MB/s eta 0:00:07
#    ---- ----------------------------------- 4.0/38.8 MB 4.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.1/38.8 MB 4.6 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.2/38.8 MB 4.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.3/38.8 MB 4.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.4/38.8 MB 4.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.5/38.8 MB 4.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.5/38.8 MB 4.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.6/38.8 MB 4.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.6/38.8 MB 3.8 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.8/38.8 MB 3.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 4.9/38.8 MB 3.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.1/38.8 MB 3.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.1/38.8 MB 3.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.1/38.8 MB 3.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.2/38.8 MB 3.6 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.6/38.8 MB 3.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.6/38.8 MB 3.7 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.7/38.8 MB 3.7 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.7/38.8 MB 3.6 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.7/38.8 MB 3.6 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.7/38.8 MB 3.6 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.7/38.8 MB 3.6 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.8/38.8 MB 3.3 MB/s eta 0:00:10
#    ------ --------------------------------- 5.9/38.8 MB 3.2 MB/s eta 0:00:11
#    ------ --------------------------------- 5.9/38.8 MB 3.2 MB/s eta 0:00:11
#    ------ --------------------------------- 6.0/38.8 MB 3.2 MB/s eta 0:00:11
#    ------ --------------------------------- 6.1/38.8 MB 3.2 MB/s eta 0:00:11
#    ------ --------------------------------- 6.1/38.8 MB 3.2 MB/s eta 0:00:11
#    ------ --------------------------------- 6.2/38.8 MB 3.1 MB/s eta 0:00:11
#    ------ --------------------------------- 6.3/38.8 MB 3.1 MB/s eta 0:00:11
#    ------ --------------------------------- 6.3/38.8 MB 3.0 MB/s eta 0:00:11
#    ------ --------------------------------- 6.3/38.8 MB 3.0 MB/s eta 0:00:11
#    ------ --------------------------------- 6.3/38.8 MB 2.9 MB/s eta 0:00:12
#    ------ --------------------------------- 6.5/38.8 MB 2.9 MB/s eta 0:00:11
#    ------ --------------------------------- 6.5/38.8 MB 2.9 MB/s eta 0:00:11
#    ------ --------------------------------- 6.5/38.8 MB 2.9 MB/s eta 0:00:11
#    ------ --------------------------------- 6.5/38.8 MB 2.8 MB/s eta 0:00:12
#    ------ --------------------------------- 6.6/38.8 MB 2.8 MB/s eta 0:00:12
#    ------ --------------------------------- 6.7/38.8 MB 2.7 MB/s eta 0:00:12
#    ------ --------------------------------- 6.7/38.8 MB 2.7 MB/s eta 0:00:12
#    ------- -------------------------------- 6.8/38.8 MB 2.7 MB/s eta 0:00:12
#    ------- -------------------------------- 6.9/38.8 MB 2.7 MB/s eta 0:00:12
#    ------- -------------------------------- 7.0/38.8 MB 2.7 MB/s eta 0:00:12
#    ------- -------------------------------- 7.1/38.8 MB 2.7 MB/s eta 0:00:12
#    ------- -------------------------------- 7.2/38.8 MB 2.7 MB/s eta 0:00:12
#    ------- -------------------------------- 7.3/38.8 MB 2.7 MB/s eta 0:00:12
#    ------- -------------------------------- 7.3/38.8 MB 2.6 MB/s eta 0:00:12
#    ------- -------------------------------- 7.3/38.8 MB 2.6 MB/s eta 0:00:12
#    ------- -------------------------------- 7.6/38.8 MB 2.7 MB/s eta 0:00:12
#    ------- -------------------------------- 7.6/38.8 MB 2.7 MB/s eta 0:00:12
#    ------- -------------------------------- 7.7/38.8 MB 2.6 MB/s eta 0:00:12
#    -------- ------------------------------- 7.8/38.8 MB 2.6 MB/s eta 0:00:12
#    -------- ------------------------------- 8.0/38.8 MB 2.6 MB/s eta 0:00:12
#    -------- ------------------------------- 8.1/38.8 MB 2.6 MB/s eta 0:00:12
#    -------- ------------------------------- 8.2/38.8 MB 2.6 MB/s eta 0:00:12
#    -------- ------------------------------- 8.4/38.8 MB 2.7 MB/s eta 0:00:12
#    -------- ------------------------------- 8.4/38.8 MB 2.6 MB/s eta 0:00:12
#    -------- ------------------------------- 8.4/38.8 MB 2.6 MB/s eta 0:00:12
#    -------- ------------------------------- 8.4/38.8 MB 2.6 MB/s eta 0:00:12
#    -------- ------------------------------- 8.4/38.8 MB 2.6 MB/s eta 0:00:12
#    -------- ------------------------------- 8.5/38.8 MB 2.5 MB/s eta 0:00:12
#    -------- ------------------------------- 8.6/38.8 MB 2.5 MB/s eta 0:00:13
#    -------- ------------------------------- 8.6/38.8 MB 2.5 MB/s eta 0:00:13
#    -------- ------------------------------- 8.7/38.8 MB 2.5 MB/s eta 0:00:13
#    --------- ------------------------------ 8.7/38.8 MB 2.5 MB/s eta 0:00:13
#    --------- ------------------------------ 8.8/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 8.9/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.0/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.1/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.2/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.3/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.5/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.5/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.5/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.6/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.6/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.6/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.6/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.6/38.8 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.6/38.8 MB 2.4 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.0/38.8 MB 2.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.0/38.8 MB 2.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.1/38.8 MB 2.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.2/38.8 MB 2.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.3/38.8 MB 2.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.4/38.8 MB 2.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.5/38.8 MB 2.2 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.6/38.8 MB 2.2 MB/s eta 0:00:13
#    ----------- ---------------------------- 10.7/38.8 MB 2.2 MB/s eta 0:00:13
#    ----------- ---------------------------- 10.8/38.8 MB 2.2 MB/s eta 0:00:13
#    ----------- ---------------------------- 11.0/38.8 MB 2.2 MB/s eta 0:00:13
#    ----------- ---------------------------- 11.0/38.8 MB 2.2 MB/s eta 0:00:13
#    ----------- ---------------------------- 11.0/38.8 MB 2.2 MB/s eta 0:00:13
#    ----------- ---------------------------- 11.1/38.8 MB 2.1 MB/s eta 0:00:13
#    ----------- ---------------------------- 11.1/38.8 MB 2.1 MB/s eta 0:00:13
#    ----------- ---------------------------- 11.1/38.8 MB 2.1 MB/s eta 0:00:13
#    ----------- ---------------------------- 11.4/38.8 MB 2.1 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.4/38.8 MB 2.1 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.4/38.8 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.4/38.8 MB 2.1 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.5/38.8 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.5/38.8 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.5/38.8 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.5/38.8 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.6/38.8 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.6/38.8 MB 2.0 MB/s eta 0:00:14
#    ------------ --------------------------- 11.7/38.8 MB 1.9 MB/s eta 0:00:14
#    ------------ --------------------------- 11.8/38.8 MB 1.9 MB/s eta 0:00:15
#    ------------ --------------------------- 11.8/38.8 MB 1.9 MB/s eta 0:00:15
#    ------------ --------------------------- 11.8/38.8 MB 1.9 MB/s eta 0:00:15
#    ------------ --------------------------- 12.2/38.8 MB 1.9 MB/s eta 0:00:15
#    ------------ --------------------------- 12.2/38.8 MB 1.9 MB/s eta 0:00:15
#    ------------ --------------------------- 12.3/38.8 MB 1.9 MB/s eta 0:00:15
#    ------------ --------------------------- 12.3/38.8 MB 1.8 MB/s eta 0:00:15
#    ------------ --------------------------- 12.4/38.8 MB 1.8 MB/s eta 0:00:15
#    ------------ --------------------------- 12.4/38.8 MB 1.8 MB/s eta 0:00:15
#    ------------ --------------------------- 12.4/38.8 MB 1.8 MB/s eta 0:00:15
#    ------------ --------------------------- 12.6/38.8 MB 1.8 MB/s eta 0:00:15
#    ------------- -------------------------- 12.7/38.8 MB 1.8 MB/s eta 0:00:15
#    ------------- -------------------------- 12.7/38.8 MB 1.8 MB/s eta 0:00:15
#    ------------- -------------------------- 12.7/38.8 MB 1.8 MB/s eta 0:00:15
#    ------------- -------------------------- 12.7/38.8 MB 1.7 MB/s eta 0:00:15
#    ------------- -------------------------- 12.8/38.8 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 12.8/38.8 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 12.9/38.8 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 13.0/38.8 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 13.1/38.8 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 13.2/38.8 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 13.2/38.8 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 13.2/38.8 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 13.4/38.8 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 13.5/38.8 MB 1.7 MB/s eta 0:00:15
#    ------------- -------------------------- 13.5/38.8 MB 1.7 MB/s eta 0:00:15
#    ------------- -------------------------- 13.5/38.8 MB 1.7 MB/s eta 0:00:15
#    ------------- -------------------------- 13.5/38.8 MB 1.7 MB/s eta 0:00:15
#    ------------- -------------------------- 13.5/38.8 MB 1.7 MB/s eta 0:00:15
#    ------------- -------------------------- 13.5/38.8 MB 1.7 MB/s eta 0:00:15
#    ------------- -------------------------- 13.5/38.8 MB 1.7 MB/s eta 0:00:15
#    ------------- -------------------------- 13.5/38.8 MB 1.6 MB/s eta 0:00:16
#    ------------- -------------------------- 13.5/38.8 MB 1.6 MB/s eta 0:00:16
#    ------------- -------------------------- 13.5/38.8 MB 1.6 MB/s eta 0:00:16
#    ------------- -------------------------- 13.5/38.8 MB 1.6 MB/s eta 0:00:16
#    ------------- -------------------------- 13.5/38.8 MB 1.6 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.6 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.6 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.5/38.8 MB 1.5 MB/s eta 0:00:17
#    ------------- -------------------------- 13.6/38.8 MB 1.4 MB/s eta 0:00:18
#    ------------- -------------------------- 13.6/38.8 MB 1.4 MB/s eta 0:00:18
#    ------------- -------------------------- 13.6/38.8 MB 1.4 MB/s eta 0:00:18
#    -------------- ------------------------- 13.6/38.8 MB 1.4 MB/s eta 0:00:18
#    -------------- ------------------------- 13.6/38.8 MB 1.4 MB/s eta 0:00:19
#    -------------- ------------------------- 13.7/38.8 MB 1.4 MB/s eta 0:00:19
#    -------------- ------------------------- 13.7/38.8 MB 1.4 MB/s eta 0:00:19
#    -------------- ------------------------- 13.7/38.8 MB 1.4 MB/s eta 0:00:19
#    -------------- ------------------------- 13.8/38.8 MB 1.4 MB/s eta 0:00:19
#    -------------- ------------------------- 13.8/38.8 MB 1.4 MB/s eta 0:00:19
#    -------------- ------------------------- 13.8/38.8 MB 1.4 MB/s eta 0:00:19
#    -------------- ------------------------- 14.0/38.8 MB 1.4 MB/s eta 0:00:19
#    -------------- ------------------------- 14.1/38.8 MB 1.4 MB/s eta 0:00:19
#    -------------- ------------------------- 14.3/38.8 MB 1.4 MB/s eta 0:00:18
#    -------------- ------------------------- 14.4/38.8 MB 1.4 MB/s eta 0:00:18
#    -------------- ------------------------- 14.5/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 14.6/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 14.6/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 14.8/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 14.9/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 15.1/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 15.2/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 15.2/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 15.2/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 15.2/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 15.2/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 15.3/38.8 MB 1.3 MB/s eta 0:00:18
#    --------------- ------------------------ 15.3/38.8 MB 1.3 MB/s eta 0:00:18
#    --------------- ------------------------ 15.4/38.8 MB 1.4 MB/s eta 0:00:18
#    --------------- ------------------------ 15.4/38.8 MB 1.3 MB/s eta 0:00:18
#    --------------- ------------------------ 15.5/38.8 MB 1.3 MB/s eta 0:00:18
#    --------------- ------------------------ 15.5/38.8 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.5/38.8 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.6/38.8 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.6/38.8 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.7/38.8 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.7/38.8 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.7/38.8 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.7/38.8 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.8/38.8 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.8/38.8 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.8/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.9/38.8 MB 1.3 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.5/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.5/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.5/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.5/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.5/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.5/38.8 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 16.5/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.0/38.8 MB 1.2 MB/s eta 0:00:18
#    ----------------- ---------------------- 17.0/38.8 MB 1.2 MB/s eta 0:00:18
#    ----------------- ---------------------- 17.0/38.8 MB 1.2 MB/s eta 0:00:18
#    ----------------- ---------------------- 17.0/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.0/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.1/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.1/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.2/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.2/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.2/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.2/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.2/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.3/38.8 MB 1.2 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.3/38.8 MB 1.1 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.3/38.8 MB 1.1 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.3/38.8 MB 1.1 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.4/38.8 MB 1.1 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.4/38.8 MB 1.1 MB/s eta 0:00:19
#    ----------------- ---------------------- 17.4/38.8 MB 1.1 MB/s eta 0:00:20
#    ----------------- ---------------------- 17.4/38.8 MB 1.1 MB/s eta 0:00:20
#    ----------------- ---------------------- 17.5/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.5/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.5/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.5/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.6/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.6/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.6/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.6/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.7/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.7/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.7/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.7/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.8/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.8/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.8/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.8/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.9/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 17.9/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 18.0/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 18.0/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 18.0/38.8 MB 1.1 MB/s eta 0:00:20
#    ------------------ --------------------- 18.1/38.8 MB 1.0 MB/s eta 0:00:20
#    ------------------ --------------------- 18.1/38.8 MB 1.0 MB/s eta 0:00:20
#    ------------------ --------------------- 18.1/38.8 MB 1.0 MB/s eta 0:00:20
#    ------------------ --------------------- 18.2/38.8 MB 1.0 MB/s eta 0:00:20
#    ------------------ --------------------- 18.2/38.8 MB 1.0 MB/s eta 0:00:21
#    ------------------ --------------------- 18.2/38.8 MB 1.0 MB/s eta 0:00:21
#    ------------------ --------------------- 18.2/38.8 MB 1.0 MB/s eta 0:00:21
#    ------------------ --------------------- 18.2/38.8 MB 1.0 MB/s eta 0:00:21
#    ------------------ --------------------- 18.3/38.8 MB 1.0 MB/s eta 0:00:21
#    ------------------ --------------------- 18.3/38.8 MB 1.0 MB/s eta 0:00:21
#    ------------------ --------------------- 18.3/38.8 MB 1.0 MB/s eta 0:00:21
#    ------------------ --------------------- 18.4/38.8 MB 1.0 MB/s eta 0:00:21
#    ------------------ --------------------- 18.4/38.8 MB 1.0 MB/s eta 0:00:21
#    ------------------- -------------------- 18.5/38.8 MB 999.6 kB/s eta 0:00:21
#    ------------------- -------------------- 18.5/38.8 MB 998.0 kB/s eta 0:00:21
#    ------------------- -------------------- 18.5/38.8 MB 996.5 kB/s eta 0:00:21
#    ------------------- -------------------- 18.6/38.8 MB 992.0 kB/s eta 0:00:21
#    ------------------- -------------------- 18.6/38.8 MB 990.5 kB/s eta 0:00:21
#    ------------------- -------------------- 18.6/38.8 MB 986.0 kB/s eta 0:00:21
#    ------------------- -------------------- 18.6/38.8 MB 983.0 kB/s eta 0:00:21
#    ------------------- -------------------- 18.6/38.8 MB 980.0 kB/s eta 0:00:21
#    ------------------- -------------------- 18.7/38.8 MB 992.0 kB/s eta 0:00:21
#    ------------------- -------------------- 18.8/38.8 MB 993.5 kB/s eta 0:00:21
#    ------------------- -------------------- 18.8/38.8 MB 990.5 kB/s eta 0:00:21
#    ------------------- -------------------- 18.9/38.8 MB 990.5 kB/s eta 0:00:21
#    ------------------- -------------------- 18.9/38.8 MB 989.0 kB/s eta 0:00:21
#    ------------------- -------------------- 19.0/38.8 MB 989.0 kB/s eta 0:00:21
#    ------------------- -------------------- 19.0/38.8 MB 987.5 kB/s eta 0:00:21
#    ------------------- -------------------- 19.0/38.8 MB 984.5 kB/s eta 0:00:21
#    ------------------- -------------------- 19.1/38.8 MB 984.6 kB/s eta 0:00:21
#    ------------------- -------------------- 19.1/38.8 MB 980.1 kB/s eta 0:00:21
#    ------------------- -------------------- 19.1/38.8 MB 978.6 kB/s eta 0:00:21
#    ------------------- -------------------- 19.2/38.8 MB 978.5 kB/s eta 0:00:21
#    ------------------- -------------------- 19.2/38.8 MB 975.7 kB/s eta 0:00:21
#    ------------------- -------------------- 19.3/38.8 MB 972.9 kB/s eta 0:00:21
#    ------------------- -------------------- 19.3/38.8 MB 971.3 kB/s eta 0:00:21
#    ------------------- -------------------- 19.3/38.8 MB 971.4 kB/s eta 0:00:21
#    ------------------- -------------------- 19.4/38.8 MB 968.5 kB/s eta 0:00:21
#    -------------------- ------------------- 19.4/38.8 MB 965.6 kB/s eta 0:00:21
#    -------------------- ------------------- 19.5/38.8 MB 962.8 kB/s eta 0:00:21
#    -------------------- ------------------- 19.5/38.8 MB 961.4 kB/s eta 0:00:21
#    -------------------- ------------------- 19.5/38.8 MB 958.6 kB/s eta 0:00:21
#    -------------------- ------------------- 19.5/38.8 MB 954.4 kB/s eta 0:00:21
#    -------------------- ------------------- 19.6/38.8 MB 952.9 kB/s eta 0:00:21
#    -------------------- ------------------- 19.6/38.8 MB 951.6 kB/s eta 0:00:21
#    -------------------- ------------------- 19.7/38.8 MB 950.3 kB/s eta 0:00:21
#    -------------------- ------------------- 19.7/38.8 MB 948.8 kB/s eta 0:00:21
#    -------------------- ------------------- 19.7/38.8 MB 948.9 kB/s eta 0:00:21
#    -------------------- ------------------- 19.8/38.8 MB 947.5 kB/s eta 0:00:21
#    -------------------- ------------------- 19.8/38.8 MB 947.5 kB/s eta 0:00:21
#    -------------------- ------------------- 19.9/38.8 MB 947.5 kB/s eta 0:00:21
#    -------------------- ------------------- 19.9/38.8 MB 962.8 kB/s eta 0:00:20
#    -------------------- ------------------- 19.9/38.8 MB 957.1 kB/s eta 0:00:20
#    -------------------- ------------------- 19.9/38.8 MB 955.8 kB/s eta 0:00:20
#    -------------------- ------------------- 20.0/38.8 MB 950.2 kB/s eta 0:00:20
#    -------------------- ------------------- 20.0/38.8 MB 946.1 kB/s eta 0:00:20
#    -------------------- ------------------- 20.0/38.8 MB 944.8 kB/s eta 0:00:20
#    -------------------- ------------------- 20.1/38.8 MB 940.7 kB/s eta 0:00:20
#    -------------------- ------------------- 20.1/38.8 MB 936.6 kB/s eta 0:00:20
#    -------------------- ------------------- 20.1/38.8 MB 936.6 kB/s eta 0:00:20
#    -------------------- ------------------- 20.2/38.8 MB 931.2 kB/s eta 0:00:21
#    -------------------- ------------------- 20.2/38.8 MB 928.6 kB/s eta 0:00:21
#    -------------------- ------------------- 20.3/38.8 MB 930.0 kB/s eta 0:00:20
#    -------------------- ------------------- 20.3/38.8 MB 928.6 kB/s eta 0:00:20
#    -------------------- ------------------- 20.3/38.8 MB 928.6 kB/s eta 0:00:20
#    -------------------- ------------------- 20.3/38.8 MB 923.4 kB/s eta 0:00:21
#    -------------------- ------------------- 20.4/38.8 MB 919.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.4/38.8 MB 919.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.4/38.8 MB 917.0 kB/s eta 0:00:21
#    --------------------- ------------------ 20.5/38.8 MB 914.4 kB/s eta 0:00:21
#    --------------------- ------------------ 20.5/38.8 MB 914.4 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.6/38.8 MB 910.5 kB/s eta 0:00:21
#    --------------------- ------------------ 20.8/38.8 MB 856.9 kB/s eta 0:00:22
#    --------------------- ------------------ 20.8/38.8 MB 856.9 kB/s eta 0:00:22
#    --------------------- ------------------ 20.8/38.8 MB 856.9 kB/s eta 0:00:22
#    --------------------- ------------------ 21.2/38.8 MB 859.2 kB/s eta 0:00:21
#    --------------------- ------------------ 21.3/38.8 MB 868.3 kB/s eta 0:00:21
#    --------------------- ------------------ 21.3/38.8 MB 868.3 kB/s eta 0:00:21
#    --------------------- ------------------ 21.3/38.8 MB 868.3 kB/s eta 0:00:21
#    --------------------- ------------------ 21.3/38.8 MB 868.3 kB/s eta 0:00:21
#    --------------------- ------------------ 21.3/38.8 MB 868.3 kB/s eta 0:00:21
#    --------------------- ------------------ 21.3/38.8 MB 868.3 kB/s eta 0:00:21
#    --------------------- ------------------ 21.3/38.8 MB 868.3 kB/s eta 0:00:21
#    ---------------------- ----------------- 21.8/38.8 MB 880.0 kB/s eta 0:00:20
#    ---------------------- ----------------- 21.9/38.8 MB 880.0 kB/s eta 0:00:20
#    ---------------------- ----------------- 21.9/38.8 MB 877.6 kB/s eta 0:00:20
#    ---------------------- ----------------- 21.9/38.8 MB 877.6 kB/s eta 0:00:20
#    ---------------------- ----------------- 22.0/38.8 MB 876.4 kB/s eta 0:00:20
#    ---------------------- ----------------- 22.0/38.8 MB 881.2 kB/s eta 0:00:20
#    ---------------------- ----------------- 22.0/38.8 MB 876.4 kB/s eta 0:00:20
#    ---------------------- ----------------- 22.1/38.8 MB 874.1 kB/s eta 0:00:20
#    ---------------------- ----------------- 22.1/38.8 MB 870.6 kB/s eta 0:00:20
#    ---------------------- ----------------- 22.1/38.8 MB 868.3 kB/s eta 0:00:20
#    ---------------------- ----------------- 22.2/38.8 MB 864.9 kB/s eta 0:00:20
#    ---------------------- ----------------- 22.2/38.8 MB 860.4 kB/s eta 0:00:20
# ...
#    ------ --------------------------------- 4.5/26.4 MB 4.4 MB/s eta 0:00:05
#    ------ --------------------------------- 4.5/26.4 MB 4.4 MB/s eta 0:00:05
#    ------ --------------------------------- 4.6/26.4 MB 4.3 MB/s eta 0:00:06
#    ------- -------------------------------- 4.7/26.4 MB 4.2 MB/s eta 0:00:06
#    ------- -------------------------------- 4.8/26.4 MB 4.1 MB/s eta 0:00:06
#    ------- -------------------------------- 4.9/26.4 MB 4.1 MB/s eta 0:00:06
#    ------- -------------------------------- 5.1/26.4 MB 4.0 MB/s eta 0:00:06
#    ------- -------------------------------- 5.2/26.4 MB 4.0 MB/s eta 0:00:06
#    -------- ------------------------------- 5.4/26.4 MB 4.0 MB/s eta 0:00:06
#    -------- ------------------------------- 5.5/26.4 MB 4.0 MB/s eta 0:00:06
#    -------- ------------------------------- 5.8/26.4 MB 4.1 MB/s eta 0:00:06
#    --------- ------------------------------ 6.0/26.4 MB 4.1 MB/s eta 0:00:05
#    --------- ------------------------------ 6.4/26.4 MB 4.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 6.7/26.4 MB 4.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 6.9/26.4 MB 4.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 7.1/26.4 MB 4.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.3/26.4 MB 4.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.3/26.4 MB 4.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.8/26.4 MB 4.5 MB/s eta 0:00:05
#    ------------ --------------------------- 8.4/26.4 MB 4.7 MB/s eta 0:00:04
#    ------------ --------------------------- 8.5/26.4 MB 4.6 MB/s eta 0:00:04
#    ------------- -------------------------- 8.7/26.4 MB 4.6 MB/s eta 0:00:04
#    ------------- -------------------------- 9.1/26.4 MB 4.7 MB/s eta 0:00:04
#    -------------- ------------------------- 9.3/26.4 MB 4.7 MB/s eta 0:00:04
#    -------------- ------------------------- 9.5/26.4 MB 4.8 MB/s eta 0:00:04
#    -------------- ------------------------- 9.7/26.4 MB 4.8 MB/s eta 0:00:04
#    --------------- ------------------------ 9.9/26.4 MB 4.8 MB/s eta 0:00:04
#    --------------- ------------------------ 10.1/26.4 MB 4.7 MB/s eta 0:00:04
#    --------------- ------------------------ 10.4/26.4 MB 4.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 10.6/26.4 MB 5.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 11.0/26.4 MB 5.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 11.3/26.4 MB 5.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 11.7/26.4 MB 4.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 11.7/26.4 MB 4.8 MB/s eta 0:00:04
#    ------------------ --------------------- 11.9/26.4 MB 5.0 MB/s eta 0:00:03
#    ------------------ --------------------- 12.1/26.4 MB 4.9 MB/s eta 0:00:03
#    ------------------ --------------------- 12.2/26.4 MB 4.9 MB/s eta 0:00:03
#    ------------------ --------------------- 12.5/26.4 MB 4.9 MB/s eta 0:00:03
#    ------------------- -------------------- 12.7/26.4 MB 4.9 MB/s eta 0:00:03
#    ------------------- -------------------- 12.7/26.4 MB 4.9 MB/s eta 0:00:03
#    ------------------- -------------------- 13.1/26.4 MB 4.9 MB/s eta 0:00:03
#    -------------------- ------------------- 13.4/26.4 MB 4.9 MB/s eta 0:00:03
#    -------------------- ------------------- 13.7/26.4 MB 5.0 MB/s eta 0:00:03
#    --------------------- ------------------ 14.0/26.4 MB 4.9 MB/s eta 0:00:03
#    --------------------- ------------------ 14.3/26.4 MB 5.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 14.6/26.4 MB 5.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 15.0/26.4 MB 5.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 15.2/26.4 MB 5.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.5/26.4 MB 5.7 MB/s eta 0:00:02
#    ------------------------ --------------- 15.9/26.4 MB 5.9 MB/s eta 0:00:02
#    ------------------------ --------------- 16.3/26.4 MB 6.0 MB/s eta 0:00:02
#    ------------------------- -------------- 16.7/26.4 MB 6.0 MB/s eta 0:00:02
#    -------------------------- ------------- 17.2/26.4 MB 6.1 MB/s eta 0:00:02
#    -------------------------- ------------- 17.8/26.4 MB 6.4 MB/s eta 0:00:02
#    --------------------------- ------------ 18.3/26.4 MB 6.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 18.7/26.4 MB 6.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 19.0/26.4 MB 6.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 19.4/26.4 MB 6.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 19.7/26.4 MB 6.6 MB/s eta 0:00:02
#    ------------------------------ --------- 20.0/26.4 MB 6.6 MB/s eta 0:00:01
#    ------------------------------ --------- 20.1/26.4 MB 6.6 MB/s eta 0:00:01
#    ------------------------------ --------- 20.4/26.4 MB 6.6 MB/s eta 0:00:01
#    ------------------------------- -------- 20.6/26.4 MB 6.5 MB/s eta 0:00:01
#    ------------------------------- -------- 20.8/26.4 MB 6.5 MB/s eta 0:00:01
#    ------------------------------- -------- 21.1/26.4 MB 6.4 MB/s eta 0:00:01
#    -------------------------------- ------- 21.4/26.4 MB 6.4 MB/s eta 0:00:01
#    -------------------------------- ------- 21.6/26.4 MB 6.3 MB/s eta 0:00:01
#    -------------------------------- ------- 21.6/26.4 MB 6.2 MB/s eta 0:00:01
#    -------------------------------- ------- 21.6/26.4 MB 6.0 MB/s eta 0:00:01
#    -------------------------------- ------- 21.7/26.4 MB 5.9 MB/s eta 0:00:01
#    -------------------------------- ------- 21.7/26.4 MB 5.8 MB/s eta 0:00:01
#    -------------------------------- ------- 21.7/26.4 MB 5.6 MB/s eta 0:00:01
#    --------------------------------- ------ 21.8/26.4 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 21.9/26.4 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 22.0/26.4 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 22.1/26.4 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 22.3/26.4 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 22.4/26.4 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.5/26.4 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.7/26.4 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.9/26.4 MB 5.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.2/26.4 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.5/26.4 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------ --- 23.8/26.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------ --- 24.2/26.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------ --- 24.2/26.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 24.7/26.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 24.9/26.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 25.1/26.4 MB 5.4 MB/s eta 0:00:01
#    -------------------------------------- - 25.5/26.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  25.8/26.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  26.4/26.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  26.4/26.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 5.4 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB 4.8 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ---------------------------------------- 71.9/71.9 kB 3.9 MB/s eta 0:00:00
# Downloading protobuf-4.25.5-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --------------------------------------- 413.4/413.4 kB 13.0 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 3.6 MB/s eta 0:00:00
# Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.6/5.5 MB 20.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.7/5.5 MB 9.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.6/5.5 MB 13.0 MB/s eta 0:00:01
#    --------------- ------------------------ 2.1/5.5 MB 13.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.3/5.5 MB 11.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.4/5.5 MB 10.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.5/5.5 MB 9.2 MB/s eta 0:00:01
#    ------------------ --------------------- 2.6/5.5 MB 8.2 MB/s eta 0:00:01
#    -------------------- ------------------- 2.8/5.5 MB 7.7 MB/s eta 0:00:01
#    -------------------- ------------------- 2.9/5.5 MB 7.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.0/5.5 MB 6.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.2/5.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.4/5.5 MB 6.6 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.5 MB 6.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.1/5.5 MB 6.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.9/5.5 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  5.4/5.5 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 7.3 MB/s eta 0:00:00
# Downloading setuptools-75.2.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.2 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.1/1.2 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 13.2 MB/s eta 0:00:00
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#    ---------------------------------------- 0.0/167.3 kB ? eta -:--:--
#    ---------------------------------------- 167.3/167.3 kB 9.8 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl (102 kB)
#    ---------------------------------------- 0.0/102.2 kB ? eta -:--:--
#    ---------------------------------------- 102.2/102.2 kB 6.1 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.4 kB ? eta -:--:--
#    ---------------------------------------- 70.4/70.4 kB ? eta 0:00:00
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#    ---------------------------------------- 0.0/106.3 kB ? eta -:--:--
#    ----------------------- ---------------- 61.4/106.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 106.3/106.3 kB 2.0 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
#    ---------------------------------------- 0.0/126.3 kB ? eta -:--:--
#    ---------------------------------------- 126.3/126.3 kB 3.7 MB/s eta 0:00:00
# Downloading werkzeug-3.0.4-py3-none-any.whl (227 kB)
#    ---------------------------------------- 0.0/227.6 kB ? eta -:--:--
#    --------------------------------------- 227.6/227.6 kB 13.6 MB/s eta 0:00:00
# Downloading wheel-0.44.0-py3-none-any.whl (67 kB)
#    ---------------------------------------- 0.0/67.1 kB ? eta -:--:--
#    ---------------------------------------- 67.1/67.1 kB ? eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Installing collected packages: pytz, namex, libclang, flatbuffers, wrapt, wheel, urllib3, tzdata, typing-extensions, tqdm, threadpoolctl, termcolor, tensorboard-data-server, setuptools, pyparsing, protobuf, pillow, opt-einsum, numpy, mdurl, MarkupSafe, markdown, kiwisolver, joblib, idna, grpcio, google-pasta, gast, fonttools, cycler, charset-normalizer, certifi, absl-py, werkzeug, scipy, requests, pandas, optree, opencv-python, ml-dtypes, markdown-it-py, h5py, contourpy, astunparse, tensorboard, scikit-learn, rich, matplotlib, seaborn, keras, tensorflow-intel, tensorflow
# Successfully installed MarkupSafe-3.0.2 absl-py-2.1.0 astunparse-1.6.3 certifi-2024.8.30 charset-normalizer-3.4.0 contourpy-1.3.0 cycler-0.12.1 flatbuffers-24.3.25 fonttools-4.54.1 gast-0.6.0 google-pasta-0.2.0 grpcio-1.67.0 h5py-3.12.1 idna-3.10 joblib-1.4.2 keras-3.6.0 kiwisolver-1.4.7 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 matplotlib-3.9.2 mdurl-0.1.2 ml-dtypes-0.4.1 namex-0.0.8 numpy-1.26.4 opencv-python-4.10.0.84 opt-einsum-3.4.0 optree-0.13.0 pandas-2.2.3 pillow-11.0.0 protobuf-4.25.5 pyparsing-3.2.0 pytz-2024.2 requests-2.32.3 rich-13.9.3 scikit-learn-1.5.2 scipy-1.14.1 seaborn-0.13.2 setuptools-75.2.0 tensorboard-2.17.1 tensorboard-data-server-0.7.2 tensorflow-2.17.0 tensorflow-intel-2.17.0 termcolor-2.5.0 threadpoolctl-3.5.0 tqdm-4.66.5 typing-extensions-4.12.2 tzdata-2024.2 urllib3-2.2.3 werkzeug-3.0.4 wheel-0.44.0 wrapt-1.16.0
#   WARNING: The script wheel.exe is installed in 'c:\Users\ashit\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\ashit\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py.exe is installed in 'c:\Users\ashit\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'c:\Users\ashit\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\ashit\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\ashit\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\ashit\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'c:\Users\ashit\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'c:\Users\ashit\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import time
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
sns.set_style('darkgrid')
import shutil
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import time
from tqdm import tqdm
from PIL import Image
from google.colab.patches import cv2_imshow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 13
#      11 from sklearn.metrics import confusion_matrix, classification_report
#      12 from sklearn.model_selection import train_test_split
# ---> 13 import tensorflow as tf
#      14 from tensorflow import keras
#      15 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# File c:\Users\ashit\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:30
#      15 """
#      16 Top-level module of TensorFlow. By convention, we refer to this module as
#      17 `tf` instead of `tensorflow`, following the common practice of importing
#    (...)
#      26 this file with a file generated from [`api_template.__init__.py`](https://www.github.com/tensorflow/tensorflow/blob/master/tensorflow/api_template.__init__.py)
#      27 """
#      28 # pylint: disable=g-bad-import-order,protected-access,g-import-not-at-top
# ---> 30 import distutils as _distutils
#      31 import importlib
#      32 import inspect as _inspect
#
# ModuleNotFoundError: No module named 'distutils'

# %% [markdown]
# **Importing data**

# %%
def make_dataframes(main_dir):
    sdir=os.path.join(main_dir,os.listdir(main_dir)[0]) # had to do this because the dataset owner keeps changing the directories name
    bad_images=[]
    good_ext=['jpg','jpeg', 'png', 'tiff']# extensions compatible with ImageDataGenerator
    filepaths=[]
    labels=[]
    classes=sorted(os.listdir(sdir))
    for klass in classes:
        classpath=os.path.join(sdir, klass)
        flist=sorted(os.listdir(classpath))
        desc=f'{klass:23s}'
        for f in tqdm(flist, ncols=110,desc=desc, unit='file', colour='blue'):
            fpath=os.path.join(classpath,f)
            fl=f.lower()
            index=fl.rfind('.')
            ext=fl[index+1:]
            if ext in good_ext:
                try:  # check for defective image files
                    img=cv2.imread(fpath)
                    shape=img.shape
                    filepaths.append(fpath)
                    labels.append(klass)
                except:
                    bad_images.append(fpath) # defective image file
                    print('defective image file: ', fpath)
            else:
                bad_images.append(fpath) # not compatible with ImageDataGenerator
    Fseries=pd.Series(filepaths, name='filepaths')
    Lseries=pd.Series(labels, name='labels')
    df=pd.concat([Fseries, Lseries], axis=1)
    # split df into a train_df, test_df and a valid_df
    train_df, dummy_df=train_test_split(df, train_size=.8, shuffle=True, random_state=123, stratify=df['labels'])
    valid_df, test_df=train_test_split(dummy_df, train_size=.5, shuffle=True, random_state=123, stratify=dummy_df['labels'])
    classes=sorted(train_df['labels'].unique())
    class_count=len(classes)
    sample_df=train_df.sample(n=50, replace=False)
    # calculate the average image height and with
    ht=0
    wt=0
    count=0
    for i in range(len(sample_df)):
        fpath=sample_df['filepaths'].iloc[i]
        try:
            img=cv2.imread(fpath)
            h=img.shape[0]
            w=img.shape[1]
            wt +=w
            ht +=h
            count +=1
        except:
            pass
    have=int(ht/count)
    wave=int(wt/count)
    aspect_ratio=have/wave
    print('number of classes in processed dataset= ', class_count)
    counts=list(train_df['labels'].value_counts())
    print('the maximum files in any class in train_df is ', max(counts), '  the minimum files in any class in train_df is ', min(counts))
    print('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
    print('average image height= ', have, '  average image width= ', wave, ' aspect ratio h/w= ', aspect_ratio)
    length=len(bad_images)
    if length >0 and length <50:
        print('Below is a list of ', length, ' defective or incompatible image files')
        for f in bad_images:
            print(f)
    return train_df, test_df, valid_df, classes, class_count


sdir=r"/content/drive/MyDrive/Code/att_img"

train_df, test_df, valid_df, classes, class_count=make_dataframes(sdir)
# Out:
# air_conditioner        : 100%|██████████████████████████████████████████| 1000/1000 [00:27<00:00, 36.35file/s]
# car_horn               : 100%|████████████████████████████████████████████| 429/429 [00:08<00:00, 48.27file/s]
# children_playing       : 100%|██████████████████████████████████████████| 1000/1000 [00:27<00:00, 36.39file/s]
# dog_bark               : 100%|██████████████████████████████████████████| 1000/1000 [00:23<00:00, 42.84file/s]
# drilling               : 100%|██████████████████████████████████████████| 1000/1000 [00:26<00:00, 37.86file/s]
# engine_idling          : 100%|██████████████████████████████████████████| 1000/1000 [00:25<00:00, 38.86file/s]
# gun_shot               : 100%|████████████████████████████████████████████| 374/374 [00:07<00:00, 50.13file/s]
# jackhammer             : 100%|██████████████████████████████████████████| 1000/1000 [00:26<00:00, 37.75file/s]
# siren                  : 100%|████████████████████████████████████████████| 929/929 [00:22<00:00, 40.43file/s]
# street_music           : 100%|██████████████████████████████████████████| 1000/1000 [00:24<00:00, 40.88file/s]
# number of classes in processed dataset=  10
# the maximum files in any class in train_df is  800   the minimum files in any class in train_df is  299
# train_df length:  6985   test_df length:  874   valid_df length:  873
# average image height=  400   average image width=  1000  aspect ratio h/w=  0.4

# %%
def balance(df, n, working_dir, img_size):
    df=df.copy()
    print('Initial length of dataframe is ', len(df))
    aug_dir=os.path.join(working_dir, 'aug')# directory to store augmented images
    if os.path.isdir(aug_dir):# start with an empty directory
        shutil.rmtree(aug_dir)
    os.mkdir(aug_dir)
    for label in df['labels'].unique():
        dir_path=os.path.join(aug_dir,label)
        os.mkdir(dir_path) # make class directories within aug directory
    # create and store the augmented images
    total=0
    gen=ImageDataGenerator(horizontal_flip=True,  rotation_range=20, width_shift_range=.05,
                                  height_shift_range=.05, zoom_range=.05)
    groups=df.groupby('labels') # group by class
    for label in df['labels'].unique():  # for every class
        group=groups.get_group(label)  # a dataframe holding only rows with the specified label
        sample_count=len(group)   # determine how many samples there are in this class
        if sample_count< n: # if the class has less than target number of images
            aug_img_count=0
            delta=n - sample_count  # number of augmented images to create
            target_dir=os.path.join(aug_dir, label)  # define where to write the images
            msg='{0:40s} for class {1:^30s} creating {2:^5s} augmented images'.format(' ', label, str(delta))
            print(msg, '\r', end='') # prints over on the same line
            aug_gen=gen.flow_from_dataframe( group,  x_col='filepaths', y_col=None, target_size=img_size,
                                            class_mode=None, batch_size=1, shuffle=False,
                                            save_to_dir=target_dir, save_prefix='aug-', color_mode='rgb',
                                            save_format='jpg')
            while aug_img_count<delta:
                images=next(aug_gen)
                aug_img_count += len(images)
            total +=aug_img_count
    print('Total Augmented images created= ', total)
    # create aug_df and merge with train_df to create composite training set ndf
    aug_fpaths=[]
    aug_labels=[]
    classlist=os.listdir(aug_dir)
    for klass in classlist:
        classpath=os.path.join(aug_dir, klass)
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            aug_fpaths.append(fpath)
            aug_labels.append(klass)
    Fseries=pd.Series(aug_fpaths, name='filepaths')
    Lseries=pd.Series(aug_labels, name='labels')
    aug_df=pd.concat([Fseries, Lseries], axis=1)
    df=pd.concat([df,aug_df], axis=0).reset_index(drop=True)
    print('Length of augmented dataframe is now ', len(df))
    return df


n=400 # number of samples in each class
working_dir=r'./' # directory to store augmented images
img_size=(300, int(300/ 0.8)) # size of augmented images
train_df=balance(train_df, n, working_dir, img_size)
# Out:
# Initial length of dataframe is  6985
# Found 343 validated image filenames.
# Found 299 validated image filenames.
# Total Augmented images created=  158
# Length of augmented dataframe is now  7143

# %%
def make_gens(batch_size, train_df, test_df, valid_df, img_size):
    trgen=ImageDataGenerator(horizontal_flip=True)
    t_and_v_gen=ImageDataGenerator()
    msg='{0:70s} for train generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    train_gen=trgen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
    msg='{0:70s} for valid generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    valid_gen=t_and_v_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
    # for the test_gen we want to calculate the batch size and test steps such that batch_size X test_steps= number of samples in test set
    # this insures that we go through all the sample in the test set exactly once.
    length=len(test_df)
    test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
    test_steps=int(length/test_batch_size)
    msg='{0:70s} for test generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    test_gen=t_and_v_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
    # from the generator we can get information we will need later
    classes=list(train_gen.class_indices.keys())
    class_indices=list(train_gen.class_indices.values())
    class_count=len(classes)
    labels=test_gen.labels
    print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)
    return train_gen, test_gen, valid_gen, test_batch_size, test_steps, classes


batch_size=64
img_size=(224,224)
train_gen, test_gen, valid_gen, test_batch_size, test_steps, classes=make_gens(batch_size, train_df, test_df, valid_df, img_size)
# Out:
# Found 7143 validated image filenames belonging to 10 classes.
# Found 873 validated image filenames belonging to 10 classes.
# Found 874 validated image filenames belonging to 10 classes.
# test batch size:  46   test steps:  19  number of classes :  10

# %%
# def create_lstm_model(sequence_length, feature_dim, num_classes):
#     # Define the LSTM model
#     model = Sequential()

#     # Add an LSTM layer with 50 units (adjust as needed) and input shape (sequence_length, feature_dim)
#     model.add(LSTM(50, input_shape=(sequence_length, feature_dim)))

#     # Add a dense layer with the appropriate number of output units (e.g., for classification)
#     model.add(Dense(num_classes, activation='softmax'))

#     # Compile the model
#     model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

#     # Display the model architecture
#     model.summary()

#     return model

# %%
def make_model(img_size, lr):
    img_shape=(img_size[0], img_size[1], 3)
    base_model=tf.keras.applications.EfficientNetV2S(include_top=False,input_shape=img_shape)
    # Note you are always told NOT to make the base model trainable initially- that is WRONG you get better results leaving it trainable
    base_model.trainable=True
    x=base_model.output
    x=Dropout(rate=.4, seed=123)(x)
    x = tf.keras.layers.GlobalAveragePooling2D(name = "GlobalAveragePooling2D_")(x)
    x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
    output=Dense(class_count, activation='sigmoid')(x)
    model=Model(inputs=base_model.input, outputs=output)
    model.compile(Adam(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
    return model
lr=.001
model=make_model(img_size, lr)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 224, 224, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv (Conv2D)        │ (None, 112, 112, 24)   │            648 │ rescaling[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_bn                   │ (None, 112, 112, 24)   │             96 │ stem_conv[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_activation           │ (None, 112, 112, 24)   │              0 │ stem_bn[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_conv      │ (None, 112, 112, 24)   │          5,184 │ stem_activation[0][0]  │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_bn        │ (None, 112, 112, 24)   │             96 │ block1a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_activati… │ (None, 112, 112, 24)   │              0 │ block1a_project_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_add (Add)         │ (None, 112, 112, 24)   │              0 │ block1a_project_activ… │
# │                           │                        │                │ stem_activation[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_conv      │ (None, 112, 112, 24)   │          5,184 │ block1a_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_bn        │ (None, 112, 112, 24)   │             96 │ block1b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_activati… │ (None, 112, 112, 24)   │              0 │ block1b_project_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_drop (Dropout)    │ (None, 112, 112, 24)   │              0 │ block1b_project_activ… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_add (Add)         │ (None, 112, 112, 24)   │              0 │ block1b_drop[0][0],    │
# │                           │                        │                │ block1a_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_conv       │ (None, 56, 56, 96)     │         20,736 │ block1b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_bn         │ (None, 56, 56, 96)     │            384 │ block2a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_activation │ (None, 56, 56, 96)     │              0 │ block2a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_conv      │ (None, 56, 56, 48)     │          4,608 │ block2a_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_bn        │ (None, 56, 56, 48)     │            192 │ block2a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_conv       │ (None, 56, 56, 192)    │         82,944 │ block2a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_bn         │ (None, 56, 56, 192)    │            768 │ block2b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_activation │ (None, 56, 56, 192)    │              0 │ block2b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_conv      │ (None, 56, 56, 48)     │          9,216 │ block2b_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_bn        │ (None, 56, 56, 48)     │            192 │ block2b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_drop (Dropout)    │ (None, 56, 56, 48)     │              0 │ block2b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_add (Add)         │ (None, 56, 56, 48)     │              0 │ block2b_drop[0][0],    │
# │                           │                        │                │ block2a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_conv       │ (None, 56, 56, 192)    │         82,944 │ block2b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_bn         │ (None, 56, 56, 192)    │            768 │ block2c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_activation │ (None, 56, 56, 192)    │              0 │ block2c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_conv      │ (None, 56, 56, 48)     │          9,216 │ block2c_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_bn        │ (None, 56, 56, 48)     │            192 │ block2c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_drop (Dropout)    │ (None, 56, 56, 48)     │              0 │ block2c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_add (Add)         │ (None, 56, 56, 48)     │              0 │ block2c_drop[0][0],    │
# │                           │                        │                │ block2b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_conv       │ (None, 56, 56, 192)    │         82,944 │ block2c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_bn         │ (None, 56, 56, 192)    │            768 │ block2d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_activation │ (None, 56, 56, 192)    │              0 │ block2d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_conv      │ (None, 56, 56, 48)     │          9,216 │ block2d_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_bn        │ (None, 56, 56, 48)     │            192 │ block2d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_drop (Dropout)    │ (None, 56, 56, 48)     │              0 │ block2d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_add (Add)         │ (None, 56, 56, 48)     │              0 │ block2d_drop[0][0],    │
# │                           │                        │                │ block2c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_conv       │ (None, 28, 28, 192)    │         82,944 │ block2d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_bn         │ (None, 28, 28, 192)    │            768 │ block3a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_activation │ (None, 28, 28, 192)    │              0 │ block3a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_conv      │ (None, 28, 28, 64)     │         12,288 │ block3a_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_bn        │ (None, 28, 28, 64)     │            256 │ block3a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_conv       │ (None, 28, 28, 256)    │        147,456 │ block3a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_bn         │ (None, 28, 28, 256)    │          1,024 │ block3b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_activation │ (None, 28, 28, 256)    │              0 │ block3b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_conv      │ (None, 28, 28, 64)     │         16,384 │ block3b_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_bn        │ (None, 28, 28, 64)     │            256 │ block3b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_drop (Dropout)    │ (None, 28, 28, 64)     │              0 │ block3b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_add (Add)         │ (None, 28, 28, 64)     │              0 │ block3b_drop[0][0],    │
# │                           │                        │                │ block3a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_conv       │ (None, 28, 28, 256)    │        147,456 │ block3b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_bn         │ (None, 28, 28, 256)    │          1,024 │ block3c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_activation │ (None, 28, 28, 256)    │              0 │ block3c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_conv      │ (None, 28, 28, 64)     │         16,384 │ block3c_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_bn        │ (None, 28, 28, 64)     │            256 │ block3c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_drop (Dropout)    │ (None, 28, 28, 64)     │              0 │ block3c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_add (Add)         │ (None, 28, 28, 64)     │              0 │ block3c_drop[0][0],    │
# │                           │                        │                │ block3b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_conv       │ (None, 28, 28, 256)    │        147,456 │ block3c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_bn         │ (None, 28, 28, 256)    │          1,024 │ block3d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_activation │ (None, 28, 28, 256)    │              0 │ block3d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_project_conv      │ (None, 28, 28, 64)     │         16,384 │ block3d_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_project_bn        │ (None, 28, 28, 64)     │            256 │ block3d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_drop (Dropout)    │ (None, 28, 28, 64)     │              0 │ block3d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_add (Add)         │ (None, 28, 28, 64)     │              0 │ block3d_drop[0][0],    │
# │                           │                        │                │ block3c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_conv       │ (None, 28, 28, 256)    │         16,384 │ block3d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_bn         │ (None, 28, 28, 256)    │          1,024 │ block4a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_activation │ (None, 28, 28, 256)    │              0 │ block4a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv2           │ (None, 14, 14, 256)    │          2,304 │ block4a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_bn                │ (None, 14, 14, 256)    │          1,024 │ block4a_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_activation        │ (None, 14, 14, 256)    │              0 │ block4a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_squeeze        │ (None, 256)            │              0 │ block4a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reshape        │ (None, 1, 1, 256)      │              0 │ block4a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reduce         │ (None, 1, 1, 16)       │          4,112 │ block4a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_expand         │ (None, 1, 1, 256)      │          4,352 │ block4a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_excite         │ (None, 14, 14, 256)    │              0 │ block4a_activation[0]… │
# │ (Multiply)                │                        │                │ block4a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_conv      │ (None, 14, 14, 128)    │         32,768 │ block4a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_bn        │ (None, 14, 14, 128)    │            512 │ block4a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_conv       │ (None, 14, 14, 512)    │         65,536 │ block4a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_bn         │ (None, 14, 14, 512)    │          2,048 │ block4b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_activation │ (None, 14, 14, 512)    │              0 │ block4b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_dwconv2           │ (None, 14, 14, 512)    │          4,608 │ block4b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_bn                │ (None, 14, 14, 512)    │          2,048 │ block4b_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_activation        │ (None, 14, 14, 512)    │              0 │ block4b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_squeeze        │ (None, 512)            │              0 │ block4b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_excite         │ (None, 14, 14, 512)    │              0 │ block4b_activation[0]… │
# │ (Multiply)                │                        │                │ block4b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_conv      │ (None, 14, 14, 128)    │         65,536 │ block4b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_bn        │ (None, 14, 14, 128)    │            512 │ block4b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_drop (Dropout)    │ (None, 14, 14, 128)    │              0 │ block4b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_add (Add)         │ (None, 14, 14, 128)    │              0 │ block4b_drop[0][0],    │
# │                           │                        │                │ block4a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_conv       │ (None, 14, 14, 512)    │         65,536 │ block4b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_bn         │ (None, 14, 14, 512)    │          2,048 │ block4c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_activation │ (None, 14, 14, 512)    │              0 │ block4c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_dwconv2           │ (None, 14, 14, 512)    │          4,608 │ block4c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_bn                │ (None, 14, 14, 512)    │          2,048 │ block4c_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_activation        │ (None, 14, 14, 512)    │              0 │ block4c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_squeeze        │ (None, 512)            │              0 │ block4c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_excite         │ (None, 14, 14, 512)    │              0 │ block4c_activation[0]… │
# │ (Multiply)                │                        │                │ block4c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_conv      │ (None, 14, 14, 128)    │         65,536 │ block4c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_bn        │ (None, 14, 14, 128)    │            512 │ block4c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_drop (Dropout)    │ (None, 14, 14, 128)    │              0 │ block4c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_add (Add)         │ (None, 14, 14, 128)    │              0 │ block4c_drop[0][0],    │
# │                           │                        │                │ block4b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_conv       │ (None, 14, 14, 512)    │         65,536 │ block4c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_bn         │ (None, 14, 14, 512)    │          2,048 │ block4d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_activation │ (None, 14, 14, 512)    │              0 │ block4d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_dwconv2           │ (None, 14, 14, 512)    │          4,608 │ block4d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_bn                │ (None, 14, 14, 512)    │          2,048 │ block4d_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_activation        │ (None, 14, 14, 512)    │              0 │ block4d_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_squeeze        │ (None, 512)            │              0 │ block4d_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4d_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4d_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4d_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_excite         │ (None, 14, 14, 512)    │              0 │ block4d_activation[0]… │
# │ (Multiply)                │                        │                │ block4d_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_project_conv      │ (None, 14, 14, 128)    │         65,536 │ block4d_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_project_bn        │ (None, 14, 14, 128)    │            512 │ block4d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_drop (Dropout)    │ (None, 14, 14, 128)    │              0 │ block4d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_add (Add)         │ (None, 14, 14, 128)    │              0 │ block4d_drop[0][0],    │
# │                           │                        │                │ block4c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_expand_conv       │ (None, 14, 14, 512)    │         65,536 │ block4d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_expand_bn         │ (None, 14, 14, 512)    │          2,048 │ block4e_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_expand_activation │ (None, 14, 14, 512)    │              0 │ block4e_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_dwconv2           │ (None, 14, 14, 512)    │          4,608 │ block4e_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_bn                │ (None, 14, 14, 512)    │          2,048 │ block4e_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_activation        │ (None, 14, 14, 512)    │              0 │ block4e_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_squeeze        │ (None, 512)            │              0 │ block4e_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4e_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4e_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4e_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_excite         │ (None, 14, 14, 512)    │              0 │ block4e_activation[0]… │
# │ (Multiply)                │                        │                │ block4e_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_project_conv      │ (None, 14, 14, 128)    │         65,536 │ block4e_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_project_bn        │ (None, 14, 14, 128)    │            512 │ block4e_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_drop (Dropout)    │ (None, 14, 14, 128)    │              0 │ block4e_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_add (Add)         │ (None, 14, 14, 128)    │              0 │ block4e_drop[0][0],    │
# │                           │                        │                │ block4d_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_expand_conv       │ (None, 14, 14, 512)    │         65,536 │ block4e_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_expand_bn         │ (None, 14, 14, 512)    │          2,048 │ block4f_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_expand_activation │ (None, 14, 14, 512)    │              0 │ block4f_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_dwconv2           │ (None, 14, 14, 512)    │          4,608 │ block4f_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_bn                │ (None, 14, 14, 512)    │          2,048 │ block4f_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_activation        │ (None, 14, 14, 512)    │              0 │ block4f_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_squeeze        │ (None, 512)            │              0 │ block4f_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4f_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4f_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4f_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_excite         │ (None, 14, 14, 512)    │              0 │ block4f_activation[0]… │
# │ (Multiply)                │                        │                │ block4f_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_project_conv      │ (None, 14, 14, 128)    │         65,536 │ block4f_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_project_bn        │ (None, 14, 14, 128)    │            512 │ block4f_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_drop (Dropout)    │ (None, 14, 14, 128)    │              0 │ block4f_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_add (Add)         │ (None, 14, 14, 128)    │              0 │ block4f_drop[0][0],    │
# │                           │                        │                │ block4e_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_conv       │ (None, 14, 14, 768)    │         98,304 │ block4f_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_bn         │ (None, 14, 14, 768)    │          3,072 │ block5a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_activation │ (None, 14, 14, 768)    │              0 │ block5a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_dwconv2           │ (None, 14, 14, 768)    │          6,912 │ block5a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_bn                │ (None, 14, 14, 768)    │          3,072 │ block5a_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_activation        │ (None, 14, 14, 768)    │              0 │ block5a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_squeeze        │ (None, 768)            │              0 │ block5a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_reshape        │ (None, 1, 1, 768)      │              0 │ block5a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_reduce         │ (None, 1, 1, 32)       │         24,608 │ block5a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_expand         │ (None, 1, 1, 768)      │         25,344 │ block5a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_excite         │ (None, 14, 14, 768)    │              0 │ block5a_activation[0]… │
# │ (Multiply)                │                        │                │ block5a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_project_conv      │ (None, 14, 14, 160)    │        122,880 │ block5a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_project_bn        │ (None, 14, 14, 160)    │            640 │ block5a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_expand_conv       │ (None, 14, 14, 960)    │        153,600 │ block5a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_expand_bn         │ (None, 14, 14, 960)    │          3,840 │ block5b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ...
# │ (Multiply)                │                        │                │ block6l_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6l_project_conv      │ (None, 7, 7, 256)      │        393,216 │ block6l_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6l_project_bn        │ (None, 7, 7, 256)      │          1,024 │ block6l_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6l_drop (Dropout)    │ (None, 7, 7, 256)      │              0 │ block6l_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6l_add (Add)         │ (None, 7, 7, 256)      │              0 │ block6l_drop[0][0],    │
# │                           │                        │                │ block6k_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_expand_conv       │ (None, 7, 7, 1536)     │        393,216 │ block6l_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_expand_bn         │ (None, 7, 7, 1536)     │          6,144 │ block6m_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_expand_activation │ (None, 7, 7, 1536)     │              0 │ block6m_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_dwconv2           │ (None, 7, 7, 1536)     │         13,824 │ block6m_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_bn                │ (None, 7, 7, 1536)     │          6,144 │ block6m_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_activation        │ (None, 7, 7, 1536)     │              0 │ block6m_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_squeeze        │ (None, 1536)           │              0 │ block6m_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_reshape        │ (None, 1, 1, 1536)     │              0 │ block6m_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_reduce         │ (None, 1, 1, 64)       │         98,368 │ block6m_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_expand         │ (None, 1, 1, 1536)     │         99,840 │ block6m_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_excite         │ (None, 7, 7, 1536)     │              0 │ block6m_activation[0]… │
# │ (Multiply)                │                        │                │ block6m_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_project_conv      │ (None, 7, 7, 256)      │        393,216 │ block6m_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_project_bn        │ (None, 7, 7, 256)      │          1,024 │ block6m_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_drop (Dropout)    │ (None, 7, 7, 256)      │              0 │ block6m_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_add (Add)         │ (None, 7, 7, 256)      │              0 │ block6m_drop[0][0],    │
# │                           │                        │                │ block6l_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_expand_conv       │ (None, 7, 7, 1536)     │        393,216 │ block6m_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_expand_bn         │ (None, 7, 7, 1536)     │          6,144 │ block6n_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_expand_activation │ (None, 7, 7, 1536)     │              0 │ block6n_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_dwconv2           │ (None, 7, 7, 1536)     │         13,824 │ block6n_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_bn                │ (None, 7, 7, 1536)     │          6,144 │ block6n_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_activation        │ (None, 7, 7, 1536)     │              0 │ block6n_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_squeeze        │ (None, 1536)           │              0 │ block6n_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_reshape        │ (None, 1, 1, 1536)     │              0 │ block6n_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_reduce         │ (None, 1, 1, 64)       │         98,368 │ block6n_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_expand         │ (None, 1, 1, 1536)     │         99,840 │ block6n_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_excite         │ (None, 7, 7, 1536)     │              0 │ block6n_activation[0]… │
# │ (Multiply)                │                        │                │ block6n_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_project_conv      │ (None, 7, 7, 256)      │        393,216 │ block6n_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_project_bn        │ (None, 7, 7, 256)      │          1,024 │ block6n_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_drop (Dropout)    │ (None, 7, 7, 256)      │              0 │ block6n_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_add (Add)         │ (None, 7, 7, 256)      │              0 │ block6n_drop[0][0],    │
# │                           │                        │                │ block6m_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_expand_conv       │ (None, 7, 7, 1536)     │        393,216 │ block6n_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_expand_bn         │ (None, 7, 7, 1536)     │          6,144 │ block6o_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_expand_activation │ (None, 7, 7, 1536)     │              0 │ block6o_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_dwconv2           │ (None, 7, 7, 1536)     │         13,824 │ block6o_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_bn                │ (None, 7, 7, 1536)     │          6,144 │ block6o_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_activation        │ (None, 7, 7, 1536)     │              0 │ block6o_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_squeeze        │ (None, 1536)           │              0 │ block6o_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_reshape        │ (None, 1, 1, 1536)     │              0 │ block6o_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_reduce         │ (None, 1, 1, 64)       │         98,368 │ block6o_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_expand         │ (None, 1, 1, 1536)     │         99,840 │ block6o_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_excite         │ (None, 7, 7, 1536)     │              0 │ block6o_activation[0]… │
# │ (Multiply)                │                        │                │ block6o_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_project_conv      │ (None, 7, 7, 256)      │        393,216 │ block6o_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_project_bn        │ (None, 7, 7, 256)      │          1,024 │ block6o_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_drop (Dropout)    │ (None, 7, 7, 256)      │              0 │ block6o_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_add (Add)         │ (None, 7, 7, 256)      │              0 │ block6o_drop[0][0],    │
# │                           │                        │                │ block6n_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_conv (Conv2D)         │ (None, 7, 7, 1280)     │        327,680 │ block6o_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_bn                    │ (None, 7, 7, 1280)     │          5,120 │ top_conv[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_activation            │ (None, 7, 7, 1280)     │              0 │ top_bn[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 7, 7, 1280)     │              0 │ top_activation[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ GlobalAveragePooling2D_   │ (None, 1280)           │              0 │ dropout[0][0]          │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 1280)           │          5,120 │ GlobalAveragePooling2… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 10)             │         12,810 │ batch_normalization[0… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 20,349,290 (77.63 MB)
#  Trainable params: 20,192,858 (77.03 MB)
#  Non-trainable params: 156,432 (611.06 KB)

# %%
epochs=10

# %%
history= model.fit(x=train_gen,  epochs= epochs, verbose=1, validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6ef3334aa11a> in <cell line: 1>()
# ----> 1 history= model.fit(x=train_gen,  epochs= epochs, verbose=1, validation_data=valid_gen, callbacks = callbacks,
#       2                validation_steps=None,  shuffle=False,  initial_epoch=0)
#
# NameError: name 'model' is not defined

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(30,10))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].scatter(Epochs, tloss, s=100, c='red')
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs', fontsize=18)
    axes[0].set_ylabel('Loss', fontsize=18)
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].scatter(Epochs, tacc, s=100, c='red')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs', fontsize=18)
    axes[1].set_ylabel('Accuracy', fontsize=18)
    axes[1].legend()
    plt.tight_layout
    plt.show()
    return index_loss

loss_index=tr_plot(history,0)

# %%
def predictor(test_gen, test_steps):
    y_pred= []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)
        true_index=test_gen.labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            errors=errors + 1
            file=test_gen.filenames[i]
        y_pred.append(pred_index)

    acc=( 1-errors/tests) * 100
    msg=f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}'
    print(msg)
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests
errors, tests=predictor(test_gen, test_steps)

# %%
working_dir=r'/content/drive/MyDrive/Code'
subject = 'Efficientnetv2S'
acc = str((1 - errors / tests) * 100)
index = acc.rfind('.')
acc = acc[:index + 3]

# Save model in Keras format (.keras)
save_id = subject + '_' + str(acc) + '.h5'
model_save_loc = os.path.join(working_dir, save_id)
model.save(model_save_loc)

msg = f'model was saved as {model_save_loc}'
print(msg)

# Save weights in HDF5 format (.h5)
save_weights_id = subject + '_weights' + str(acc) + '.weights.h5'
model_weights_save_loc = os.path.join(working_dir, save_weights_id)
model.save_weights(model_weights_save_loc)

msg1 = f'model weights were saved as {model_weights_save_loc}'
print(msg1)
